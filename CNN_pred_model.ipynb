# %%
# !pip install tensorflowjs
# Out:
# Requirement already satisfied: tensorflowjs in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (4.22.0)
# Requirement already satisfied: flax>=0.7.2 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (0.10.3)
# Requirement already satisfied: importlib_resources>=5.9.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (6.5.2)
# Requirement already satisfied: jax>=0.4.13 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (0.4.34)
# Requirement already satisfied: jaxlib>=0.4.13 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (0.4.34)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (2.15.1)
# Requirement already satisfied: tf-keras>=2.13.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (2.15.1)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (1.8.1)
# Requirement already satisfied: six<2,>=1.16.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (1.16.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (0.16.1)
# Requirement already satisfied: packaging~=23.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflowjs) (23.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from flax>=0.7.2->tensorflowjs) (1.26.4)
# Requirement already satisfied: msgpack in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.11.5)
# Requirement already satisfied: tensorstore in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.1.72)
# Requirement already satisfied: rich>=11.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from flax>=0.7.2->tensorflowjs) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from flax>=0.7.2->tensorflowjs) (4.12.2)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.1.9)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from jax>=0.4.13->tensorflowjs) (0.3.2)
# Requirement already satisfied: opt-einsum in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from jax>=0.4.13->tensorflowjs) (1.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.15.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (4.25.6)
# Requirement already satisfied: setuptools in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (1.70.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.15.0)
# Requirement already satisfied: pandas in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: wheel in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.44.0)
# Requirement already satisfied: wurlitzer in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.15.1)
# Requirement already satisfied: chex>=0.1.87 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.88)
# Requirement already satisfied: etils[epy] in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from optax->flax>=0.7.2->tensorflowjs) (1.12.0)
# Requirement already satisfied: nest_asyncio in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.12.1)
# Requirement already satisfied: simplejson>=3.16.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.2)
# Requirement already satisfied: toolz>=0.9.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2024.12.0)
# Requirement already satisfied: zipp in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.21.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (2.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\palla\anaconda3\envs\notebook\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow<3,>=2.13.0->tensorflowjs) (3.2.2)

# %%
# Importing the needed modules
import tensorflow as tf
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import torch.nn as nn
import torch
import keras
from keras.activations import get
from art.estimators.classification import TensorFlowV2Classifier
from art.attacks.evasion import FastGradientMethod
from art.utils import load_dataset
matplotlib.rcParams.update({"font.size": 14})
# Out:
# WARNING:tensorflow:From c:\Users\palla\anaconda3\envs\notebook\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# LOADING OUR DATA (MNIST FILE - which contains all hand drawn digits from 0-9)

# %%
(train_images, train_labels), (test_images, test_labels), min, max = load_dataset(name="mnist")

# %% [markdown]
# ## Training a TensorFlow Keras model

# %%
def create_model():
    model = tf.keras.models.Sequential([
        Conv2D(filters=32, kernel_size=3, activation="relu", input_shape=(28, 28, 1)),
        MaxPool2D(pool_size=2),
        Conv2D(filters=64, kernel_size=3, activation="relu"),
        MaxPool2D(pool_size=2),
        Flatten(),        
        Dense(units=10, activation="softmax")])
    model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])
    return model

# %%
model = create_model()
model.fit(x=train_images,y=train_labels, epochs=10,batch_size=256)
# Out:
# WARNING:tensorflow:From c:\Users\palla\anaconda3\envs\notebook\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\palla\anaconda3\envs\notebook\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\palla\anaconda3\envs\notebook\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\palla\anaconda3\envs\notebook\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\palla\anaconda3\envs\notebook\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 235/235 [==============================] - 10s 39ms/step - loss: 0.3823 - accuracy: 0.9028
# Epoch 2/10
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0916 - accuracy: 0.9722
# Epoch 3/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0640 - accuracy: 0.9803
# Epoch 4/10
# 235/235 [==============================] - 9s 37ms/step - loss: 0.0528 - accuracy: 0.9840
# Epoch 5/10
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0451 - accuracy: 0.9860
# Epoch 6/10
# 235/235 [==============================] - 10s 41ms/step - loss: 0.0397 - accuracy: 0.9880
# Epoch 7/10
# 235/235 [==============================] - 10s 43ms/step - loss: 0.0346 - accuracy: 0.9894
# Epoch 8/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0312 - accuracy: 0.9905
# Epoch 9/10
# 235/235 [==============================] - 9s 40ms/step - loss: 0.0274 - accuracy: 0.9910
# Epoch 10/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0248 - accuracy: 0.9926
